# %%
import pandas as pd
import datetime as dt
from datetime import timedelta

# %%
date_before=(dt.datetime.now().date()-timedelta(days=1)).strftime("%m-%d-%Y")

# %%
url = r"https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/"+date_before+".csv"

# %%
data=pd.read_csv(url, error_bad_lines=False)
# Out:
#                            Province/State      Country/Region  \
# 0                                   Hubei      Mainland China
# 1                                     NaN         South Korea
# 2                                     NaN               Italy
# 3                               Guangdong      Mainland China
# 4                                   Henan      Mainland China
# 5                                Zhejiang      Mainland China
# 6                                   Hunan      Mainland China
# 7                                   Anhui      Mainland China
# 8                                     NaN                Iran
# 9                                 Jiangxi      Mainland China
# 10                               Shandong      Mainland China
# 11           Diamond Princess cruise ship              Others
# 12                                Jiangsu      Mainland China
# 13                              Chongqing      Mainland China
# ...
